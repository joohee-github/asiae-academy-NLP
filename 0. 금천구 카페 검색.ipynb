# %%
import pandas as pd

# %%
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\user\.conda\envs\study1\lib\site-packages (1.2.0)

# %%
import xlrd

# %%
df = pd.read_excel('도로명정보조회.xlsx')
df
# Out:
#         도로명
# 0   서해안고속도로
# 1     남부순환로
# 2      시흥대로
# 3      안양천로
# 4      가마산로
# 5       금하로
# 6       기아로
# 7      디지털로
# 8       범안로
# 9       호암로
# 10      벚꽃로
# 11  가산디지털1로
# 12  가산디지털2로
# 13      가산로
# 14      독산로
# 15      두산로
# 16    은행나무로
# 17      탑골로
# 18      한내로
# 19      문성로
# 20    강남순환로
# 21     서부샛길
# 22     삼성산길

# %%
# dict -> list

list1 = df.values.tolist()
list1
add_li = []
for i in list1:
    for j in i:
        print(j)
        add_li.append(j)
# Out:
# 서해안고속도로
# 남부순환로
# 시흥대로
# 안양천로
# 가마산로
# 금하로
# 기아로
# 디지털로
# 범안로
# 호암로
# 벚꽃로
# 가산디지털1로
# 가산디지털2로
# 가산로
# 독산로
# 두산로
# 은행나무로
# 탑골로
# 한내로
# 문성로
# 강남순환로
# 서부샛길
# 삼성산길

# %%
print(add_li)
# Out:
# ['서해안고속도로', '남부순환로', '시흥대로', '안양천로', '가마산로', '금하로', '기아로', '디지털로', '범안로', '호암로', '벚꽃로', '가산디지털1로', '가산디지털2로', '가산로', '독산로', '두산로', '은행나무로', '탑골로', '한내로', '문성로', '강남순환로', '서부샛길', '삼성산길']

# %%
new_li = []
for ro in add_li:
    new_li.append('금천구 {} 카페'.format(ro))
    
new_li
# Out:
# ['금천구 서해안고속도로 카페',
#  '금천구 남부순환로 카페',
#  '금천구 시흥대로 카페',
#  '금천구 안양천로 카페',
#  '금천구 가마산로 카페',
#  '금천구 금하로 카페',
#  '금천구 기아로 카페',
#  '금천구 디지털로 카페',
#  '금천구 범안로 카페',
#  '금천구 호암로 카페',
#  '금천구 벚꽃로 카페',
#  '금천구 가산디지털1로 카페',
#  '금천구 가산디지털2로 카페',
#  '금천구 가산로 카페',
#  '금천구 독산로 카페',
#  '금천구 두산로 카페',
#  '금천구 은행나무로 카페',
#  '금천구 탑골로 카페',
#  '금천구 한내로 카페',
#  '금천구 문성로 카페',
#  '금천구 강남순환로 카페',
#  '금천구 서부샛길 카페',
#  '금천구 삼성산길 카페']

# %%
import requests
from bs4 import BeautifulSoup

# %%
import json

# %%
for i in new_li:

# %%
    base_url = 'https://map.naver.com/v5/api/search'
    params = {
        'caller':'pcweb',
        'query': '금천구 범안로 카페',
        'type':'all',
        'searchCoord':'126.88415050506593;37.48030724508602',
        'page':'1',
        'displayCount':'100',
        'isPlaceRecommendationReplace':'true',
        'lang':'ko'
    }
    headers = {
        'user-agent' :  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'
    }
    
resp = requests.get(base_url,params=params,headers=headers)
resp
# Out:
# <Response [200]>

# %%
data = json.loads(resp.text)
data
# Out:
# {'result': {'type': 'place',
#   'metaInfo': {'pageId': 'UyQTLwpy8cviXdHZNFR-273296',
#    'sessionId': '7JIakOnAtZK+AOWQQ9k/92gC',
#    'rcode': '09530103',
#    'searchedQuery': '금천구 범안로 카페',
#    'correction': None,
#    'displayCorrectAnswer': False},
#   'address': None,
#   'place': {'page': 1,
#    'totalCount': 36,
#    'boundary': ['126.8638940', '37.4666729', '126.8962748', '37.4513306'],
#    'feedback': ["<strong>'서울특별시 금천구'</strong>",
#     "근처 <strong>'범안로 카페'</strong>"],
#    'options': {'sort': '0', 'toggleLocation': '0', 'rank': '1'},
#    'filters': {},
#    'reSearch': None,
#    'isSiteSortAvailable': False,
#    'specializedSearch': None,
#    'hasPollingPlace': False,
#    'isAdultKeyword': False,
#    'containAdultContents': False,
#    'address': None,
#    'brandPromotion': None,
#    'list': [{'index': '0',
#      'rank': '1',
#      'id': '1738549510',
#      'name': '2ro2ro',
#      'tel': '070-4150-2525',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['카페,디저트', '케이크전문'],
#      'categoryPath': [['220036', '220052', '220565', '221177'],
#       ['222606', '222607', '1004380', '1002043']],
#      'address': '서울특별시 금천구 가산동 685',
#      'roadAddress': '서울특별시 금천구 범안로 1130 디지털엠파이어빌딩 1층 106호',
#      'abbrAddress': '가산동 685',
#      'shortAddress': ['서울 금천구', '범안로 1130', '디지털엠파이어빌딩 1층 106호'],
#      'display': '2ro2ro',
#      'telDisplay': '070-4150-2525',
#      'context': [],
#      'reviewCount': 47,
#      'ktCallMd': 'ae31255a8789d6003d7a7c6e5b10e1b1',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200217_214/1581866117026J4vTU_JPEG/Xn4S0ObP7VHcPPJm5Cun5h79.jpeg.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8876322',
#      'y': '37.4656414',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'GqZwM0T/Ofc5uxq0ryGLVA==',
#       'pan': '154.56',
#       'tilt': '10.00',
#       'lng': '126.8874839',
#       'lat': '37.4659520',
#       'fov': '120'},
#      'skyPanorama': {'id': '3z1zQD0w8aGA7Nym0RD9Cw==',
#       'pan': '84.42',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4652176',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://instagram.com/maca_doongcaroon',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.8874595,
#         'y': 37.4649939}],
#       'walk': [{'rep': True, 'x': 126.8879437, 'y': 37.4659504},
#        {'rep': False, 'x': 126.887928, 'y': 37.4651802}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 08:00~20:00 평일 고정, 공휴일은 변동 | 일요일 휴무 | 토요일 12:00~18:00',
#      'menuInfo': '마카둥카롱 변동가격(업주문의) | 커스텀 레터링 케이크 변동가격(업주문의) | 벚꽃로밀크티 변동가격(업주문의) | 순우유 멜론케이크 변동가격(업주문의)',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1660.89',
#      'marker': 'nres://marker/00063-00013',
#      'markerSelected': 'nres://marker/00063-00166',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '1',
#      'rank': '2',
#      'id': '38314620',
#      'name': '카페로드',
#      'tel': '02-803-3337',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004380', '1002043']],
#      'address': '서울특별시 금천구 독산동 1003',
#      'roadAddress': '서울특별시 금천구 범안로 1152',
#      'abbrAddress': '독산동 1003',
#      'shortAddress': ['서울 금천구', '범안로 1152'],
#      'display': '<b>카페</b>로드',
#      'telDisplay': '02-803-3337',
#      'context': ['카페', '오레오빙수', '치즈빙수', '편안한', '나들이'],
#      'reviewCount': 31,
#      'ktCallMd': 'f1ca8e8b62a5bd43954b5fbaaf4533cd',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20191218_216/15766534259188sWna_JPEG/image.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8898329',
#      'y': '37.4663363',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '2NeL9uiO+RrvaX2Ah4RjsA==',
#       'pan': '170.83',
#       'tilt': '10.00',
#       'lng': '126.8898058',
#       'lat': '37.4665029',
#       'fov': '120'},
#      'skyPanorama': {'id': 'UFB5dDgks9yV7YBY5QI29g==',
#       'pan': '-91.77',
#       'tilt': '-30.00',
#       'lng': '126.8936081',
#       'lat': '37.4664497',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.889758,
#         'y': 37.466284}],
#       'walk': [{'rep': True, 'x': 126.889879, 'y': 37.466446}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 08:00~24:00 | 주말 09:00~24:00',
#      'menuInfo': '아메리카노 3,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/296607',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': True,
#      'reservationLabel': {'standard': False,
#       'preOrder': True,
#       'table': False,
#       'takeout': True},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': True,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1633.83',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '2',
#      'rank': '3',
#      'id': '18517513',
#      'name': '파리바게뜨 독산역점',
#      'tel': '02-896-5668',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['카페,디저트', '베이커리'],
#      'categoryPath': [['220036', '220052', '220564', '221176'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 독산동 1003',
#      'roadAddress': '서울특별시 금천구 범안로 1152',
#      'abbrAddress': '독산동 1003',
#      'shortAddress': ['서울 금천구', '범안로 1152'],
#      'display': '파리바게뜨 독산역점',
#      'telDisplay': '02-896-5668',
#      'context': [],
#      'reviewCount': 17,
#      'ktCallMd': '24646233bd9baaef0d47ababefe08c2e',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20190122_68/1548145541961kX1CK_JPEG/QQagfymtIRAiZHIm5746SALL.jpeg.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8898698',
#      'y': '37.4663710',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'ViPlrOzvNXJ+V92rA/ZRYg==',
#       'pan': '69.57',
#       'tilt': '7.88',
#       'lng': '126.8896400',
#       'lat': '37.4663550',
#       'fov': '38'},
#      'skyPanorama': {'id': 'UFB5dDgks9yV7YBY5QI29g==',
#       'pan': '-91.25',
#       'tilt': '-30.00',
#       'lng': '126.8936081',
#       'lat': '37.4664497',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.paris.co.kr/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.889758,
#         'y': 37.466284}],
#       'walk': [{'rep': True, 'x': 126.889879, 'y': 37.466446}]},
#      'isPollingPlace': False,
#      'bizhourInfo': None,
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1631.16',
#      'marker': 'nres://marker/00063-00013',
#      'markerSelected': 'nres://marker/00063-00166',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '3',
#      'rank': '4',
#      'id': '37801261',
#      'name': '본죽&비빔밥cafe 독산역점',
#      'tel': '02-858-6288',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['음식점', '죽'],
#      'categoryPath': [['220036', '220037', '220060', '232122', '1000602'],
#       ['220036', '220037', '220060', '232122', '220619']],
#      'address': '서울특별시 금천구 가산동 685',
#      'roadAddress': '서울특별시 금천구 범안로 1130 디지털엠파이어빌딩',
#      'abbrAddress': '가산동 685',
#      'shortAddress': ['서울 금천구', '범안로 1130', '디지털엠파이어빌딩'],
#      'display': '본죽&비빔밥cafe 독산역점',
#      'telDisplay': '02-858-6288',
#      'context': [],
#      'reviewCount': 3,
#      'ktCallMd': '913fa634694fc6243dc653da0033f7da',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200526_243/1590457742832twj3i_JPEG/18CrVPcmMZJUdDUSbC14oJXD.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8877458',
#      'y': '37.4655570',
#      'itemLevel': '11',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '8d8vdVu0hlBO/RYtcORYoA==',
#       'pan': '-106.68',
#       'tilt': '10.00',
#       'lng': '126.8881566',
#       'lat': '37.4656797',
#       'fov': '120'},
#      'skyPanorama': {'id': '3z1zQD0w8aGA7Nym0RD9Cw==',
#       'pan': '85.65',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4652176',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'https://www.bonif.co.kr/menu/list?brdCd=BF101',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.8874595,
#         'y': 37.4649939}],
#       'walk': [{'rep': True, 'x': 126.8879437, 'y': 37.4659504},
#        {'rep': False, 'x': 126.887928, 'y': 37.4651802}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 09:30~21:30 | 주말 10:00~20:00',
#      'menuInfo': '매콤낙지비빔밥 8,500 | 본나물비빔밥 7,000 | 버섯불고기비빔밥 9,000 | 전복죽 11,000 | 트러플전복죽 16,000 | 쇠고기야채죽 9,000 | 삼계죽 11,000 | 삼계전복죽 15,000 | 낙지김치죽 9,500 | 홍게품은죽 13,000 | 신짬뽕죽 10,000 | 불낙죽 11,000 | 양구펀치볼시래기바지락죽 9,500 | 6가지야채죽 8,000 | 단호박죽 9,000 | 동지팥죽 9,000 | 불낙뚝배기 9,500 | 해물뚝배기 9,000 | 봄냉이바지락죽 9,000 | 냉이바지락강된장비빔밥 9,500 | 곤드레떡갈비한상 11,000 | 해물김치해장죽 10,000 | 맥적구이열무비빔밥 8,500',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1672.00',
#      'marker': 'nres://marker/00063-00122',
#      'markerSelected': 'nres://marker/00063-00276',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '4',
#      'rank': '5',
#      'id': '1254502294',
#      'name': '커피주',
#      'tel': '02-2626-6447',
#      'isCallLink': False,
#      'virtualTel': '0507-1327-6447',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 가산동 687 대륭21차 101-1호',
#      'roadAddress': '서울특별시 금천구 범안로 1126 대륭21차 101-1호',
#      'abbrAddress': '가산동 687 대륭21차 101-1호',
#      'shortAddress': ['서울 금천구', '범안로 1126', '대륭21차 101-1호'],
#      'display': '커피주',
#      'telDisplay': '02-2626-6447',
#      'context': [],
#      'reviewCount': 9,
#      'ktCallMd': 'bab41a944614c6aacce39f3228b6d94a',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20190705_106/1562308684211g7idS_JPEG/9HUCAxalgwVhGRd3h6srji0m.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8870641',
#      'y': '37.4657479',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'pEPLaWhagqOcAjaGrBHRag==',
#       'pan': '170.35',
#       'tilt': '10.00',
#       'lng': '126.8870506',
#       'lat': '37.4658266',
#       'fov': '120'},
#      'skyPanorama': {'id': 'COocHrKfYUL6MVueG4NGTQ==',
#       'pan': '96.81',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4661903',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': None,
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 08:00~20:00 | 토요일 12:00~18:00 매주 일요일은 휴무',
#      'menuInfo': '딸기라떼  5,000 | 초코땅콩프라페 4,800 | 흑임자크림라떼 4,500 | 아메리카노(HOT&ICE)가격동일 2,500',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1640.63',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '5',
#      'rank': '6',
#      'id': '1632832475',
#      'name': '모임공간모카플레이스',
#      'tel': '02-868-4154',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['서비스,산업', '장소대여'],
#      'categoryPath': [['225111', '225130', '229970', '229971']],
#      'address': '서울특별시 금천구 가산동 685',
#      'roadAddress': '서울특별시 금천구 범안로 1130 214호 모카플레이스',
#      'abbrAddress': '가산동 685',
#      'shortAddress': ['서울 금천구', '범안로 1130', '214호 모카플레이스'],
#      'display': '모임공간모카플레이스',
#      'telDisplay': '02-868-4154',
#      'context': [],
#      'reviewCount': 2,
#      'ktCallMd': '8e68d84f154379ff2d9ccedbb27f842b',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20180620_245/1529485155758P8VKX_JPEG/5lxZBMWlsw0W0NihkSRJT9xC.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8877458',
#      'y': '37.4655570',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '8d8vdVu0hlBO/RYtcORYoA==',
#       'pan': '-106.68',
#       'tilt': '10.00',
#       'lng': '126.8881566',
#       'lat': '37.4656797',
#       'fov': '120'},
#      'skyPanorama': {'id': '3z1zQD0w8aGA7Nym0RD9Cw==',
#       'pan': '85.65',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4652176',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'https://spacecloud.kr/space/14072',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.8874595,
#         'y': 37.4649939}],
#       'walk': [{'rep': True, 'x': 126.8879437, 'y': 37.4659504},
#        {'rep': False, 'x': 126.887928, 'y': 37.4651802}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 09:00~23:00',
#      'menuInfo': '회의(세미나)공간-주간 15,000 | 회의(세미나)공간-주말 20,000 | 파티(모임)공간-주간 25,000 | 파티(모임)공간-주말 30,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1672.00',
#      'marker': 'nres://marker/00063-00035',
#      'markerSelected': 'nres://marker/00063-00188',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '6',
#      'rank': '7',
#      'id': '1062946851',
#      'name': '공간ABC',
#      'tel': '010-3307-9196',
#      'isCallLink': False,
#      'virtualTel': '0507-1322-9196',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 독산동 1007-13',
#      'roadAddress': '서울특별시 금천구 범안로 1212 이편안세상 오피스텔 상가 104호 공간ABC',
#      'abbrAddress': '독산동 1007-13',
#      'shortAddress': ['서울 금천구', '범안로 1212', '이편안세상 오피스텔 상가 104호 공간ABC'],
#      'display': '공간ABC',
#      'telDisplay': '010-3307-9196',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': '47825076d00d132d7e682dcf9b11558f',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200523_235/1590180706416qSAyT_JPEG/l-KLc4ZLbbz5gKo03Janj5kw.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8962748',
#      'y': '37.4662736',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '6Wb+0UQ/4x6EH48hLEW7OA==',
#       'pan': '177.32',
#       'tilt': '10.00',
#       'lng': '126.8962640',
#       'lat': '37.4664971',
#       'fov': '120'},
#      'skyPanorama': {'id': 'UFB5dDgks9yV7YBY5QI29g==',
#       'pan': '93.83',
#       'tilt': '-30.00',
#       'lng': '126.8936081',
#       'lat': '37.4664497',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': None,
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 09:00~21:00',
#      'menuInfo': '공간ABC쥬스 3,900 | 딸바쥬스 3,900 | 망고스무디 4,300 | 레몬에이드 3,900 | 자몽차 3,300 | 바닐라카페라떼ICE 3,500 | 흑당버블밀크티  4,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1893.68',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '7',
#      'rank': '8',
#      'id': '1012458830',
#      'name': '데스트로커피',
#      'tel': '02-868-3255',
#      'isCallLink': False,
#      'virtualTel': '0507-1363-3255',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 가산동 715',
#      'roadAddress': '서울특별시 금천구 범안로 1138 101-1호',
#      'abbrAddress': '가산동 715',
#      'shortAddress': ['서울 금천구', '범안로 1138', '101-1호'],
#      'display': '데스트로커피',
#      'telDisplay': '02-868-3255',
#      'context': [],
#      'reviewCount': 4,
#      'ktCallMd': '658f1de4132ba3e3315bc0a06b273837',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20190722_35/1563785671856pBDMz_JPEG/9FXnFY_qeTCIW32SRZsZTz0E.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8883982',
#      'y': '37.4657937',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'z9YTjwOHam5Hy9E2aQz+xg==',
#       'pan': '85.36',
#       'tilt': '10.00',
#       'lng': '126.8881212',
#       'lat': '37.4657710',
#       'fov': '120'},
#      'skyPanorama': {'id': 'QOpYoVt/Ujjhf9zOU+OEjQ==',
#       'pan': '-173.66',
#       'tilt': '-30.00',
#       'lng': '126.8888092',
#       'lat': '37.4694443',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.instagram.com/destro_coffee',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.888369,
#         'y': 37.465378}],
#       'walk': [{'rep': True, 'x': 126.8881861, 'y': 37.4657996}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 08:00~21:00 | 주말 10:00~17:00',
#      'menuInfo': '에스프레소 2,900 | 아메리카노 2,900 | 카페라떼 3,500 | 카푸치노 3,500 | 바닐라라떼 3,900 | 카페모카 3,900 | 카라멜마끼야또 3,900 | 초코라떼 3,800 | 레몬에이드 4,300 | 자몽에이드 4,300 | 요거트스무디 4,000 | 딸기요거트스무디 4,500 | 블루베리요거트스무디 4,500 | 미숫가루 4,000 | 제주봄빛그린티라떼 4,200 | 고구마라떼 4,200 | 청포도에이드 4,100 | 잉글리쉬 브랙패스트 3,000 | 얼그레이 3,000 | 페퍼민트 3,000 | 카모마일 3,000 | 토마토주스 4,100 | 키위주스 4,100',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1658.22',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '8',
#      'rank': '9',
#      'id': '1550852077',
#      'name': '카페윈썸',
#      'tel': '010-5435-3765',
#      'isCallLink': False,
#      'virtualTel': '0507-1301-3765',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 독산동 1007-13',
#      'roadAddress': '서울특별시 금천구 범안로 1212 상업시설 B07호 카페윈썸',
#      'abbrAddress': '독산동 1007-13',
#      'shortAddress': ['서울 금천구', '범안로 1212', '상업시설 B07호 카페윈썸'],
#      'display': '<b>카페</b>윈썸',
#      'telDisplay': '010-5435-3765',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': 'e7ee5ea5a05a9a98e588236d3f0889d9',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200313_136/1584077004364Nd3dR_JPEG/nvNnQQzS0wu84vyMI_SSdYzC.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8962641',
#      'y': '37.4660352',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'OPEWDHelRnJOEnNkdQMNZA==',
#       'pan': '87.03',
#       'tilt': '10.00',
#       'lng': '126.8958895',
#       'lat': '37.4660155',
#       'fov': '120'},
#      'skyPanorama': {'id': 'UFB5dDgks9yV7YBY5QI29g==',
#       'pan': '98.92',
#       'tilt': '-30.00',
#       'lng': '126.8936081',
#       'lat': '37.4664497',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://instagram.com/cafe_winsome ',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.896658,
#         'y': 37.4659243},
#        {'rep': False, 'x': 126.8959125, 'y': 37.4654874}],
#       'walk': None},
#      'isPollingPlace': False,
#      'bizhourInfo': '토요일 09:00~21:00 | 목요일 09:00~21:00 | 금요일 09:00~21:00 | 수요일 09:00~21:00 | 화요일 09:00~21:00 | 월요일 09:00~21:00 | 공휴일 12:00~18:00 | 일요일 12:00~18:00',
#      'menuInfo': '아메리카노 3,500 | 리얼초코 5,500',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/337515',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': True,
#      'reservationLabel': {'standard': False,
#       'preOrder': True,
#       'table': False,
#       'takeout': True},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': True,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1915.09',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '9',
#      'rank': '10',
#      'id': '21795497',
#      'name': '빅푸드시스템',
#      'tel': '02-3667-9497',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 독산동 1003-5',
#      'roadAddress': '서울특별시 금천구 범안로 1162 4층402호',
#      'abbrAddress': '독산동 1003-5',
#      'shortAddress': ['서울 금천구', '범안로 1162', '4층402호'],
#      'display': '빅푸드시스템',
#      'telDisplay': '02-3667-9497',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': '1a4a32ac4a87f47ea943c47086f6eba8',
#      'coupon': '0',
#      'thumUrl': None,
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8909240',
#      'y': '37.4662070',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'W8eeqBXeDv7jOE7nj8Y9bw==',
#       'pan': '176.76',
#       'tilt': '10.00',
#       'lng': '126.8909061',
#       'lat': '37.4665146',
#       'fov': '120'},
#      'skyPanorama': {'id': 'UFB5dDgks9yV7YBY5QI29g==',
#       'pan': '-95.21',
#       'tilt': '-30.00',
#       'lng': '126.8936081',
#       'lat': '37.4664497',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.atimellow.com/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.890834,
#         'y': 37.466407}],
#       'walk': [{'rep': True, 'x': 126.890834, 'y': 37.466407}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 00:00~24:00',
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1679.40',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '10',
#      'rank': '11',
#      'id': '1355921434',
#      'name': 'GS25 독산우시장점',
#      'tel': '02-6015-6222',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['생활,편의', '편의점'],
#      'categoryPath': [['223267', '223271', '223309'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 독산동 293-21',
#      'roadAddress': '서울특별시 금천구 범안로 1201',
#      'abbrAddress': '독산동 293-21',
#      'shortAddress': ['서울 금천구', '범안로 1201'],
#      'display': 'GS25 독산우시장점',
#      'telDisplay': '02-6015-6222',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': '982d529e7ef854f3aaeefe1ba6ae2253',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200429_46/1588128581843dWhxn_JPEG/6Jimd-SH0NobmW0HBafiVQcz.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8953492',
#      'y': '37.4666729',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '7UTcvqdqm6q3BQL1VeJfWQ==',
#       'pan': '-23.91',
#       'tilt': '5.38',
#       'lng': '126.8954148',
#       'lat': '37.4665069',
#       'fov': '38'},
#      'skyPanorama': {'id': 'UFB5dDgks9yV7YBY5QI29g==',
#       'pan': '82.73',
#       'tilt': '-30.00',
#       'lng': '126.8936081',
#       'lat': '37.4664497',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': None,
#      'isPollingPlace': False,
#      'bizhourInfo': None,
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1811.29',
#      'marker': 'nres://marker/00063-00052',
#      'markerSelected': 'nres://marker/00063-00205',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '11',
#      'rank': '12',
#      'id': '1634193652',
#      'name': '명장시대',
#      'tel': '02-898-1883',
#      'isCallLink': False,
#      'virtualTel': '0507-1330-1883',
#      'ppc': '1',
#      'category': ['카페,디저트', '베이커리'],
#      'categoryPath': [['220036', '220052', '220564', '221161'],
#       ['222606', '222607', '1004380', '1004381', '1004382']],
#      'address': '경기도 광명시 하안동 342-3',
#      'roadAddress': '경기도 광명시 범안로 930 명장시대',
#      'abbrAddress': '하안동 342-3',
#      'shortAddress': ['경기 광명시', '범안로 930', '명장시대'],
#      'display': '명장시대',
#      'telDisplay': '02-898-1883',
#      'context': [],
#      'reviewCount': 689,
#      'ktCallMd': 'abe9b2b02e33a268a1ed8ec29df10e09',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200512_127/1589288788754gXHCd_JPEG/sHr3SzKediC-VHIJViUEFoMa.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8684659',
#      'y': '37.4553749',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'HumfTwKFOqNxR/IRvR8ljg==',
#       'pan': '149.66',
#       'tilt': '28.18',
#       'lng': '126.8681708',
#       'lat': '37.4558059',
#       'fov': '100'},
#      'skyPanorama': {'id': 'It9kmsbOtWjtA8YDD2ls1g==',
#       'pan': '-106.06',
#       'tilt': '-30.00',
#       'lng': '126.8702774',
#       'lat': '37.4558945',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': None,
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 10:00~22:00',
#      'menuInfo': '내마음속 시나몬 6,000 | 그린올리바 1,500 | 둥근산 연인 6,500 | 와인스틱 6,000 | 찹쌀떡 1,600 | 견과류 카스테라 4,300 | 무화과 깜빠뉴 5,000 | 크림치즈 깜빠뉴 6,000 | 뺑오쇼콜라 3,500 | 베이비크림치즈 2,500 | 나가사키 카스테라 4,500 | 머랭쿠키 5,000 | 인절미빵 6,000 | 프룬스콘 2,800 | 얼그레이스콘 2,800 | 유자찰치즈 3,900 | 시크릿플라워 5,300 | 치즈브리오슈 6,000 | 소세지빵 4,500 | 우리밀 바닐라 3,300 | 브라우니쿠키 3,000 | 레몬파이 4,200 | 애플파이 2,800 | 밤크로와상 5,500 | 폴인크루아상 2,800 | 딸기생크림 7,000 | 당근케이크 6,000 | 기리쉬케이크 6,000 | 티라미수 6,000 | 녹차티라미수 6,000 | 블루베리타르트 5,000 | 망고타르트 5,000 | 딸기타르트 5,000 | 레몬타르트 5,000 | 쇼콜라타르트 5,000 | 크림치즈토르테 5,000 | 에그타르트 2,500 | 먹물치아바타 샌드위치 4,500 | 치아바타 샌드위치 4,500 | 팥빵 2,200 | 어니언크림치즈 6,000 | 딸기크루아상 4,500 | 봄의왈츠 5,800 | 오곡쿠키 6,000 | 건강러스크 2,000 | 코코앤망고 3,500 | 베이비만쥬 6,000 | 브라우니볼 4,800',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '3101.39',
#      'marker': 'nres://marker/00063-00013',
#      'markerSelected': 'nres://marker/00063-00166',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '12',
#      'rank': '13',
#      'id': '1840461185',
#      'name': '라그레이',
#      'tel': '010-2547-3495',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004380', '1004381', '1004382']],
#      'address': '경기도 광명시 하안동 296-3',
#      'roadAddress': '경기도 광명시 범안로 1030',
#      'abbrAddress': '하안동 296-3',
#      'shortAddress': ['경기 광명시', '범안로 1030'],
#      'display': '라그레이',
#      'telDisplay': '010-2547-3495',
#      'context': [],
#      'reviewCount': 113,
#      'ktCallMd': '963d6afd071be708623d682b187270d1',
#      'coupon': '0',
#      'thumUrl': None,
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8778247',
#      'y': '37.4612098',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '3Gneq5nF8Nn0GYsM03R+PA==',
#       'pan': '134.60',
#       'tilt': '10.00',
#       'lng': '126.8776818',
#       'lat': '37.4613505',
#       'fov': '120'},
#      'skyPanorama': {'id': '7CBuyoMCuCJ3NMuGB7loVA==',
#       'pan': '-83.60',
#       'tilt': '-30.00',
#       'lng': '126.8834457',
#       'lat': '37.4605751',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.instagram.com/la__grey',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.877881,
#         'y': 37.461376}],
#       'walk': [{'rep': True, 'x': 126.877881, 'y': 37.461376}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 11:00~20:00 (마카롱 소진시 마감)',
#      'menuInfo': '마카롱 2,000 | 아메리카노 2,500',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '2197.58',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '13',
#      'rank': '14',
#      'id': '835973645',
#      'name': '옴마카롱',
#      'tel': '010-2087-2502',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['카페,디저트', '베이커리'],
#      'categoryPath': [['220036', '220052', '220564', '221161'],
#       ['222606', '222607', '1004380', '1004381', '1004382']],
#      'address': '경기도 광명시 하안동 33-6',
#      'roadAddress': '경기도 광명시 범안로 1061 삼전빌딩 4층',
#      'abbrAddress': '하안동 33-6',
#      'shortAddress': ['경기 광명시', '범안로 1061', '삼전빌딩 4층'],
#      'display': '옴마카롱',
#      'telDisplay': '010-2087-2502',
#      'context': [],
#      'reviewCount': 71,
#      'ktCallMd': 'e38c9d622b54e1f25be19f6b08db3f61',
#      'coupon': '0',
#      'thumUrl': None,
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8803078',
#      'y': '37.4632277',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '72ZA9V1BQK63ylZYrg8v0A==',
#       'pan': '-40.86',
#       'tilt': '10.00',
#       'lng': '126.8804548',
#       'lat': '37.4630577',
#       'fov': '120'},
#      'skyPanorama': {'id': '8vbRslFMgubh1Q1uTref6A==',
#       'pan': '-90.74',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4632645',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.instagram.com/om_macaron',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True, 'x': 126.880325, 'y': 37.46336}],
#       'walk': [{'rep': True, 'x': 126.8803, 'y': 37.463102}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '월요일 휴무 | 매일 11:00~20:00 조금씩 다를 수 있음 | 주말 12:00~17:00 조금씩 다를 수 있음',
#      'menuInfo': '마카롱 2,500',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1930.86',
#      'marker': 'nres://marker/00063-00013',
#      'markerSelected': 'nres://marker/00063-00166',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '14',
#      'rank': '15',
#      'id': '1375564182',
#      'name': '르하임스터디카페 광명하안점',
#      'tel': '010-6348-7899',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['서비스,산업', '장소대여'],
#      'categoryPath': [['225111', '225130', '229970', '229971'],
#       ['222606', '222607', '1004380', '1004381', '1004382']],
#      'address': '경기도 광명시 하안동 34-5 성원빌딩 8층',
#      'roadAddress': '경기도 광명시 범안로 1049 성원빌딩 8층',
#      'abbrAddress': '하안동 34-5 성원빌딩 8층',
#      'shortAddress': ['경기 광명시', '범안로 1049', '성원빌딩 8층'],
#      'display': '르하임스터디<b>카페</b> 광명하안점',
#      'telDisplay': '010-6348-7899',
#      'context': [],
#      'reviewCount': 97,
#      'ktCallMd': '82bd99762b83be4319d766185cc2fe87',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20180721_173/15321461817399eMaK_JPEG/lv9OKj99Ar_08dusglPXBNSY.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8793078',
#      'y': '37.4627190',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'AHcs8Koh+GIJwzYL8yAPiw==',
#       'pan': '-34.16',
#       'tilt': '10.00',
#       'lng': '126.8794551',
#       'lat': '37.4625020',
#       'fov': '120'},
#      'skyPanorama': {'id': '8vbRslFMgubh1Q1uTref6A==',
#       'pan': '-97.77',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4632645',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'https://blog.naver.com/siso0435',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.8791654,
#         'y': 37.4627628}],
#       'walk': [{'rep': True, 'x': 126.8793508, 'y': 37.4628762}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 00:00~24:00 연중무휴',
#      'menuInfo': '2시간 3,000 | 4시간 5,000 | 6시간 6,000 | 9시간 8,000 | 12시간 10,000 | 50시간 정액권 70,000 | 100시간 정액권 120,000 | 4주 기간권 120,000 | 4인 스터디룸 1시간 7,000 | 4인 스터디룸 20시간 정액권 120,000 | 4인 스터디룸 30시간 정액권 180,000 | 6인 스터디룸 1시간 10,000 | 6인 스터디룸 20시간 정액권 180,000 | 6인 스터디룸 30시간 정액권 270,000 | 8인 스터디룸  1시간 12,000 | 8인 스터디룸 20시간 정액권 220,000 | 8인 스터디룸 30시간 정액권 330,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '2003.60',
#      'marker': 'nres://marker/00063-00035',
#      'markerSelected': 'nres://marker/00063-00188',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '15',
#      'rank': '16',
#      'id': '35788342',
#      'name': '스타벅스 광명하안점',
#      'tel': '1522-3232',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['카페,디저트', '카페'],
#      'categoryPath': [['220036', '220052', '220576', '221275']],
#      'address': '경기도 광명시 하안동 53-3',
#      'roadAddress': '경기도 광명시 범안로 1060',
#      'abbrAddress': '하안동 53-3',
#      'shortAddress': ['경기 광명시', '범안로 1060'],
#      'display': '스타벅스 광명하안점',
#      'telDisplay': '1522-3232',
#      'context': [],
#      'reviewCount': 46,
#      'ktCallMd': '7e663c2a3a77ea5bf4110dbb3eb6abfb',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20190828_93/1566953601239OT9MQ_PNG/xX7Wv642gXMoTI0DAv0hRymS.png',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8805770',
#      'y': '37.4626050',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'YUq+3OLBH59N5XNlztvnKg==',
#       'pan': '112.06',
#       'tilt': '6.31',
#       'lng': '126.8802800',
#       'lat': '37.4627877',
#       'fov': '63'},
#      'skyPanorama': {'id': '8vbRslFMgubh1Q1uTref6A==',
#       'pan': '-103.52',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4632645',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.starbucks.co.kr/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.880603,
#         'y': 37.462524}],
#       'walk': [{'rep': True, 'x': 126.880541, 'y': 37.46278}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '화요일 07:00~22:00 | 수요일 07:00~22:00 | 목요일 07:00~22:00 | 금요일 07:00~22:00 | 토요일 07:00~22:00 | 일요일 08:00~22:00 | 월요일 07:00~22:00',
#      'menuInfo': '블론드 서머 라떼 5,900 | 스위티 자몽&라임 블렌디드 6,300 | 스위트 멜론 블렌디드 6,300 | 카페 아메리카노 4,100 | 디카페인 카페 아메리카노 4,400 | 카페 라떼 4,600 | 디카페인 카페 라뗴 4,900 | 오늘의 커피 3,800 | 스타벅스 돌체 라떼 5,600 | 카라멜 마키아또 5,600 | 카푸치노 4,600 | 카페 모카 5,100 | 화이트 초콜릿 모카 5,600 | 콜드 브루 4,500 | 자몽 허니 블랙 티 5,300 | 아이스 자몽 허니 블랙 티 5,300 | 망고 바나나 블렌디드 6,300 | 에스프레소 프라푸치노 5,100 | 자바 칩 프라푸치노 6,100',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
# ...
#       'pan': '-40.86',
#       'tilt': '10.00',
#       'lng': '126.8804548',
#       'lat': '37.4630577',
#       'fov': '120'},
#      'skyPanorama': {'id': '8vbRslFMgubh1Q1uTref6A==',
#       'pan': '-90.74',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4632645',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True, 'x': 126.880325, 'y': 37.46336}],
#       'walk': [{'rep': True, 'x': 126.8803, 'y': 37.463102}]},
#      'isPollingPlace': False,
#      'bizhourInfo': None,
#      'menuInfo': '오징어볶음 10,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1930.86',
#      'marker': 'nres://marker/00063-00122',
#      'markerSelected': 'nres://marker/00063-00276',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '31',
#      'rank': '32',
#      'id': '37535308',
#      'name': '티움심리상담센터',
#      'tel': '02-898-2777',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['건강,의료', '심리상담'],
#      'categoryPath': [['223175', '223180', '223196'],
#       ['222606', '222607', '1004380', '1004381', '1004382']],
#      'address': '경기도 광명시 하안동 36 골드프라자 5층',
#      'roadAddress': '경기도 광명시 범안로 1040',
#      'abbrAddress': '하안동 36 골드프라자 5층',
#      'shortAddress': ['경기 광명시', '범안로 1040'],
#      'display': '티움심리상담센터',
#      'telDisplay': '02-898-2777',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': 'c1aa1bb87b5250cb9cff313fca64f86e',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20160201_32/1454324726581v5JPV_JPEG/176077533664766_0.jpeg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8787075',
#      'y': '37.4616493',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '7SdS0fHi7x79msYK2kiGeg==',
#       'pan': '147.07',
#       'tilt': '10.00',
#       'lng': '126.8785708',
#       'lat': '37.4618599',
#       'fov': '120'},
#      'skyPanorama': {'id': '/Bm0DOs5sWrP3iGsZIYxwQ==',
#       'pan': '-100.27',
#       'tilt': '-30.00',
#       'lng': '126.8834991',
#       'lat': '37.4625130',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.tiumcafe.net',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.878837,
#         'y': 37.4615729}],
#       'walk': [{'rep': True, 'x': 126.8786007, 'y': 37.4617207}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 09:00~21:00',
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '2131.38',
#      'marker': 'nres://marker/00063-00035',
#      'markerSelected': 'nres://marker/00063-00188',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '32',
#      'rank': '33',
#      'id': '1139506342',
#      'name': '포텐스터디센터 하안점',
#      'tel': '010-4695-9253',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['교육,학문', '독서실'],
#      'categoryPath': [['222412', '222415', '222446', '231974']],
#      'address': '경기도 광명시 하안동 34-10',
#      'roadAddress': '경기도 광명시 범안로 1041',
#      'abbrAddress': '하안동 34-10',
#      'shortAddress': ['경기 광명시', '범안로 1041'],
#      'display': '포텐스터디센터 하안점',
#      'telDisplay': '010-4695-9253',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': '95bdb93b727b2fd25836fef7699482ce',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200618_5/1592443569956RyPA7_JPEG/Ohtkgr6nvjGSLZYkw_9bq0a5.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8784852',
#      'y': '37.4622410',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'VByGYSpJPmDON4ke6Is/VQ==',
#       'pan': '-42.82',
#       'tilt': '10.00',
#       'lng': '126.8786553',
#       'lat': '37.4620573',
#       'fov': '120'},
#      'skyPanorama': {'id': '8vbRslFMgubh1Q1uTref6A==',
#       'pan': '-101.98',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4632645',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'https://potenstudy.creatorlink.net/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.878363,
#         'y': 37.462336}],
#       'walk': [{'rep': True, 'x': 126.878594, 'y': 37.462177}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 00:00~24:00',
#      'menuInfo': '1시간(커피/음료/쿠키 무료) 2,000 | 2시간(커피/음료/쿠키 무료) 3,000 | 4시간(커피/음료/쿠키 무료) 5,000 | 6시간(커피/음료/쿠키 무료) 6,000 | 2인 스터디룸 6,000 | 4인 스터디룸 8,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '2071.94',
#      'marker': 'nres://marker/00063-00035',
#      'markerSelected': 'nres://marker/00063-00188',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '33',
#      'rank': '34',
#      'id': '18939012',
#      'name': 'GS25 광명유창점',
#      'tel': '02-897-7864',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['생활,편의', '편의점'],
#      'categoryPath': [['223267', '223271', '223309'],
#       ['222606', '222607', '1004380', '1004381', '1004382']],
#      'address': '경기도 광명시 하안동 33-5 유창빌딩 102호',
#      'roadAddress': '경기도 광명시 범안로 1059 유창빌딩',
#      'abbrAddress': '하안동 33-5 유창빌딩 102호',
#      'shortAddress': ['경기 광명시', '범안로 1059', '유창빌딩'],
#      'display': 'GS25 광명유창점',
#      'telDisplay': '02-897-7864',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': 'b2f035602ded665fe34d2aa7a184701f',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200121_31/1579571495458ARLtG_JPEG/2ug5eW43vnQfXFFyfpkdQEwn.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8800850',
#      'y': '37.4630371',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'rWG2sAJGQdh8rGwsj1VJBw==',
#       'pan': '-25.52',
#       'tilt': '10.00',
#       'lng': '126.8801548',
#       'lat': '37.4628910',
#       'fov': '120'},
#      'skyPanorama': {'id': '8vbRslFMgubh1Q1uTref6A==',
#       'pan': '-94.05',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4632645',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://gs25.gsretail.com/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.8799914,
#         'y': 37.4631923}],
#       'walk': [{'rep': True, 'x': 126.8802048, 'y': 37.4630671}]},
#      'isPollingPlace': False,
#      'bizhourInfo': None,
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1955.26',
#      'marker': 'nres://marker/00063-00052',
#      'markerSelected': 'nres://marker/00063-00205',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '34',
#      'rank': '35',
#      'id': '18937935',
#      'name': 'GS25 광명녹원점',
#      'tel': '02-897-9545',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['생활,편의', '편의점'],
#      'categoryPath': [['223267', '223271', '223309'], ['223267', '223284']],
#      'address': '경기도 광명시 하안동 302 녹원프라자 106,107호',
#      'roadAddress': '경기도 광명시 범안로 998',
#      'abbrAddress': '하안동 302 녹원프라자 106,107호',
#      'shortAddress': ['경기 광명시', '범안로 998'],
#      'display': 'GS25 광명녹원점',
#      'telDisplay': '02-897-9545',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': '090b7a71a6691909bf8fba5cfc528112',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200121_31/1579571495458ARLtG_JPEG/2ug5eW43vnQfXFFyfpkdQEwn.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8748731',
#      'y': '37.4593564',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'nlG1eHuNvJNPm94eu5zM4w==',
#       'pan': '133.55',
#       'tilt': '10.00',
#       'lng': '126.8746590',
#       'lat': '37.4595596',
#       'fov': '120'},
#      'skyPanorama': {'id': 'I8CLAvMaOEruDmGOE7cQ4A==',
#       'pan': '80.90',
#       'tilt': '-30.00',
#       'lng': '126.8701172',
#       'lat': '37.4585915',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://gs25.gsretail.com/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.875041,
#         'y': 37.459411}],
#       'walk': [{'rep': True, 'x': 126.874876, 'y': 37.459575}]},
#      'isPollingPlace': False,
#      'bizhourInfo': None,
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '2471.44',
#      'marker': 'nres://marker/00063-00052',
#      'markerSelected': 'nres://marker/00063-00205',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '35',
#      'rank': '36',
#      'id': '32160934',
#      'name': 'GS25 광명프라자점',
#      'tel': '02-898-1767',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['생활,편의', '편의점'],
#      'categoryPath': [['223267', '223271', '223309'],
#       ['222606', '222607', '1004452']],
#      'address': '경기도 광명시 하안동 36 골드프라자 105호',
#      'roadAddress': '경기도 광명시 범안로 1040',
#      'abbrAddress': '하안동 36 골드프라자 105호',
#      'shortAddress': ['경기 광명시', '범안로 1040'],
#      'display': 'GS25 광명프라자점',
#      'telDisplay': '02-898-1767',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': 'c0c390452e1438a132667dae6292e424',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200121_31/1579571495458ARLtG_JPEG/2ug5eW43vnQfXFFyfpkdQEwn.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8785798',
#      'y': '37.4616598',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '1iy/7hUc8ET9U6mwApqdlQ==',
#       'pan': '143.10',
#       'tilt': '10.00',
#       'lng': '126.8784715',
#       'lat': '37.4618038',
#       'fov': '120'},
#      'skyPanorama': {'id': '/Bm0DOs5sWrP3iGsZIYxwQ==',
#       'pan': '-99.89',
#       'tilt': '-30.00',
#       'lng': '126.8834991',
#       'lat': '37.4625130',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://gs25.gsretail.com/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.878837,
#         'y': 37.4615729}],
#       'walk': [{'rep': True, 'x': 126.8786007, 'y': 37.4617207}]},
#      'isPollingPlace': False,
#      'bizhourInfo': None,
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '2132.82',
#      'marker': 'nres://marker/00063-00052',
#      'markerSelected': 'nres://marker/00063-00205',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None}]},
#   'bus': None}}

# %%
data = data.select

# %%
tags = soup.select('list')
tags
# Out:
# []

# %%
data = json.loads(resp.text)
data
# Out:
# {'result': {'type': 'place',
#   'metaInfo': {'pageId': 'UyQTLwpy8cviXdHZNFR-273296',
#    'sessionId': '7JIakOnAtZK+AOWQQ9k/92gC',
#    'rcode': '09530103',
#    'searchedQuery': '금천구 범안로 카페',
#    'correction': None,
#    'displayCorrectAnswer': False},
#   'address': None,
#   'place': {'page': 1,
#    'totalCount': 36,
#    'boundary': ['126.8638940', '37.4666729', '126.8962748', '37.4513306'],
#    'feedback': ["<strong>'서울특별시 금천구'</strong>",
#     "근처 <strong>'범안로 카페'</strong>"],
#    'options': {'sort': '0', 'toggleLocation': '0', 'rank': '1'},
#    'filters': {},
#    'reSearch': None,
#    'isSiteSortAvailable': False,
#    'specializedSearch': None,
#    'hasPollingPlace': False,
#    'isAdultKeyword': False,
#    'containAdultContents': False,
#    'address': None,
#    'brandPromotion': None,
#    'list': [{'index': '0',
#      'rank': '1',
#      'id': '1738549510',
#      'name': '2ro2ro',
#      'tel': '070-4150-2525',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['카페,디저트', '케이크전문'],
#      'categoryPath': [['220036', '220052', '220565', '221177'],
#       ['222606', '222607', '1004380', '1002043']],
#      'address': '서울특별시 금천구 가산동 685',
#      'roadAddress': '서울특별시 금천구 범안로 1130 디지털엠파이어빌딩 1층 106호',
#      'abbrAddress': '가산동 685',
#      'shortAddress': ['서울 금천구', '범안로 1130', '디지털엠파이어빌딩 1층 106호'],
#      'display': '2ro2ro',
#      'telDisplay': '070-4150-2525',
#      'context': [],
#      'reviewCount': 47,
#      'ktCallMd': 'ae31255a8789d6003d7a7c6e5b10e1b1',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200217_214/1581866117026J4vTU_JPEG/Xn4S0ObP7VHcPPJm5Cun5h79.jpeg.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8876322',
#      'y': '37.4656414',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'GqZwM0T/Ofc5uxq0ryGLVA==',
#       'pan': '154.56',
#       'tilt': '10.00',
#       'lng': '126.8874839',
#       'lat': '37.4659520',
#       'fov': '120'},
#      'skyPanorama': {'id': '3z1zQD0w8aGA7Nym0RD9Cw==',
#       'pan': '84.42',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4652176',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://instagram.com/maca_doongcaroon',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.8874595,
#         'y': 37.4649939}],
#       'walk': [{'rep': True, 'x': 126.8879437, 'y': 37.4659504},
#        {'rep': False, 'x': 126.887928, 'y': 37.4651802}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 08:00~20:00 평일 고정, 공휴일은 변동 | 일요일 휴무 | 토요일 12:00~18:00',
#      'menuInfo': '마카둥카롱 변동가격(업주문의) | 커스텀 레터링 케이크 변동가격(업주문의) | 벚꽃로밀크티 변동가격(업주문의) | 순우유 멜론케이크 변동가격(업주문의)',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1660.89',
#      'marker': 'nres://marker/00063-00013',
#      'markerSelected': 'nres://marker/00063-00166',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '1',
#      'rank': '2',
#      'id': '38314620',
#      'name': '카페로드',
#      'tel': '02-803-3337',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004380', '1002043']],
#      'address': '서울특별시 금천구 독산동 1003',
#      'roadAddress': '서울특별시 금천구 범안로 1152',
#      'abbrAddress': '독산동 1003',
#      'shortAddress': ['서울 금천구', '범안로 1152'],
#      'display': '<b>카페</b>로드',
#      'telDisplay': '02-803-3337',
#      'context': ['카페', '오레오빙수', '치즈빙수', '편안한', '나들이'],
#      'reviewCount': 31,
#      'ktCallMd': 'f1ca8e8b62a5bd43954b5fbaaf4533cd',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20191218_216/15766534259188sWna_JPEG/image.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8898329',
#      'y': '37.4663363',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '2NeL9uiO+RrvaX2Ah4RjsA==',
#       'pan': '170.83',
#       'tilt': '10.00',
#       'lng': '126.8898058',
#       'lat': '37.4665029',
#       'fov': '120'},
#      'skyPanorama': {'id': 'UFB5dDgks9yV7YBY5QI29g==',
#       'pan': '-91.77',
#       'tilt': '-30.00',
#       'lng': '126.8936081',
#       'lat': '37.4664497',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.889758,
#         'y': 37.466284}],
#       'walk': [{'rep': True, 'x': 126.889879, 'y': 37.466446}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 08:00~24:00 | 주말 09:00~24:00',
#      'menuInfo': '아메리카노 3,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/296607',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': True,
#      'reservationLabel': {'standard': False,
#       'preOrder': True,
#       'table': False,
#       'takeout': True},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': True,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1633.83',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '2',
#      'rank': '3',
#      'id': '18517513',
#      'name': '파리바게뜨 독산역점',
#      'tel': '02-896-5668',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['카페,디저트', '베이커리'],
#      'categoryPath': [['220036', '220052', '220564', '221176'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 독산동 1003',
#      'roadAddress': '서울특별시 금천구 범안로 1152',
#      'abbrAddress': '독산동 1003',
#      'shortAddress': ['서울 금천구', '범안로 1152'],
#      'display': '파리바게뜨 독산역점',
#      'telDisplay': '02-896-5668',
#      'context': [],
#      'reviewCount': 17,
#      'ktCallMd': '24646233bd9baaef0d47ababefe08c2e',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20190122_68/1548145541961kX1CK_JPEG/QQagfymtIRAiZHIm5746SALL.jpeg.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8898698',
#      'y': '37.4663710',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'ViPlrOzvNXJ+V92rA/ZRYg==',
#       'pan': '69.57',
#       'tilt': '7.88',
#       'lng': '126.8896400',
#       'lat': '37.4663550',
#       'fov': '38'},
#      'skyPanorama': {'id': 'UFB5dDgks9yV7YBY5QI29g==',
#       'pan': '-91.25',
#       'tilt': '-30.00',
#       'lng': '126.8936081',
#       'lat': '37.4664497',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.paris.co.kr/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.889758,
#         'y': 37.466284}],
#       'walk': [{'rep': True, 'x': 126.889879, 'y': 37.466446}]},
#      'isPollingPlace': False,
#      'bizhourInfo': None,
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1631.16',
#      'marker': 'nres://marker/00063-00013',
#      'markerSelected': 'nres://marker/00063-00166',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '3',
#      'rank': '4',
#      'id': '37801261',
#      'name': '본죽&비빔밥cafe 독산역점',
#      'tel': '02-858-6288',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['음식점', '죽'],
#      'categoryPath': [['220036', '220037', '220060', '232122', '1000602'],
#       ['220036', '220037', '220060', '232122', '220619']],
#      'address': '서울특별시 금천구 가산동 685',
#      'roadAddress': '서울특별시 금천구 범안로 1130 디지털엠파이어빌딩',
#      'abbrAddress': '가산동 685',
#      'shortAddress': ['서울 금천구', '범안로 1130', '디지털엠파이어빌딩'],
#      'display': '본죽&비빔밥cafe 독산역점',
#      'telDisplay': '02-858-6288',
#      'context': [],
#      'reviewCount': 3,
#      'ktCallMd': '913fa634694fc6243dc653da0033f7da',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200526_243/1590457742832twj3i_JPEG/18CrVPcmMZJUdDUSbC14oJXD.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8877458',
#      'y': '37.4655570',
#      'itemLevel': '11',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '8d8vdVu0hlBO/RYtcORYoA==',
#       'pan': '-106.68',
#       'tilt': '10.00',
#       'lng': '126.8881566',
#       'lat': '37.4656797',
#       'fov': '120'},
#      'skyPanorama': {'id': '3z1zQD0w8aGA7Nym0RD9Cw==',
#       'pan': '85.65',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4652176',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'https://www.bonif.co.kr/menu/list?brdCd=BF101',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.8874595,
#         'y': 37.4649939}],
#       'walk': [{'rep': True, 'x': 126.8879437, 'y': 37.4659504},
#        {'rep': False, 'x': 126.887928, 'y': 37.4651802}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 09:30~21:30 | 주말 10:00~20:00',
#      'menuInfo': '매콤낙지비빔밥 8,500 | 본나물비빔밥 7,000 | 버섯불고기비빔밥 9,000 | 전복죽 11,000 | 트러플전복죽 16,000 | 쇠고기야채죽 9,000 | 삼계죽 11,000 | 삼계전복죽 15,000 | 낙지김치죽 9,500 | 홍게품은죽 13,000 | 신짬뽕죽 10,000 | 불낙죽 11,000 | 양구펀치볼시래기바지락죽 9,500 | 6가지야채죽 8,000 | 단호박죽 9,000 | 동지팥죽 9,000 | 불낙뚝배기 9,500 | 해물뚝배기 9,000 | 봄냉이바지락죽 9,000 | 냉이바지락강된장비빔밥 9,500 | 곤드레떡갈비한상 11,000 | 해물김치해장죽 10,000 | 맥적구이열무비빔밥 8,500',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1672.00',
#      'marker': 'nres://marker/00063-00122',
#      'markerSelected': 'nres://marker/00063-00276',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '4',
#      'rank': '5',
#      'id': '1254502294',
#      'name': '커피주',
#      'tel': '02-2626-6447',
#      'isCallLink': False,
#      'virtualTel': '0507-1327-6447',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 가산동 687 대륭21차 101-1호',
#      'roadAddress': '서울특별시 금천구 범안로 1126 대륭21차 101-1호',
#      'abbrAddress': '가산동 687 대륭21차 101-1호',
#      'shortAddress': ['서울 금천구', '범안로 1126', '대륭21차 101-1호'],
#      'display': '커피주',
#      'telDisplay': '02-2626-6447',
#      'context': [],
#      'reviewCount': 9,
#      'ktCallMd': 'bab41a944614c6aacce39f3228b6d94a',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20190705_106/1562308684211g7idS_JPEG/9HUCAxalgwVhGRd3h6srji0m.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8870641',
#      'y': '37.4657479',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'pEPLaWhagqOcAjaGrBHRag==',
#       'pan': '170.35',
#       'tilt': '10.00',
#       'lng': '126.8870506',
#       'lat': '37.4658266',
#       'fov': '120'},
#      'skyPanorama': {'id': 'COocHrKfYUL6MVueG4NGTQ==',
#       'pan': '96.81',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4661903',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': None,
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 08:00~20:00 | 토요일 12:00~18:00 매주 일요일은 휴무',
#      'menuInfo': '딸기라떼  5,000 | 초코땅콩프라페 4,800 | 흑임자크림라떼 4,500 | 아메리카노(HOT&ICE)가격동일 2,500',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1640.63',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '5',
#      'rank': '6',
#      'id': '1632832475',
#      'name': '모임공간모카플레이스',
#      'tel': '02-868-4154',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['서비스,산업', '장소대여'],
#      'categoryPath': [['225111', '225130', '229970', '229971']],
#      'address': '서울특별시 금천구 가산동 685',
#      'roadAddress': '서울특별시 금천구 범안로 1130 214호 모카플레이스',
#      'abbrAddress': '가산동 685',
#      'shortAddress': ['서울 금천구', '범안로 1130', '214호 모카플레이스'],
#      'display': '모임공간모카플레이스',
#      'telDisplay': '02-868-4154',
#      'context': [],
#      'reviewCount': 2,
#      'ktCallMd': '8e68d84f154379ff2d9ccedbb27f842b',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20180620_245/1529485155758P8VKX_JPEG/5lxZBMWlsw0W0NihkSRJT9xC.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8877458',
#      'y': '37.4655570',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '8d8vdVu0hlBO/RYtcORYoA==',
#       'pan': '-106.68',
#       'tilt': '10.00',
#       'lng': '126.8881566',
#       'lat': '37.4656797',
#       'fov': '120'},
#      'skyPanorama': {'id': '3z1zQD0w8aGA7Nym0RD9Cw==',
#       'pan': '85.65',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4652176',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'https://spacecloud.kr/space/14072',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.8874595,
#         'y': 37.4649939}],
#       'walk': [{'rep': True, 'x': 126.8879437, 'y': 37.4659504},
#        {'rep': False, 'x': 126.887928, 'y': 37.4651802}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 09:00~23:00',
#      'menuInfo': '회의(세미나)공간-주간 15,000 | 회의(세미나)공간-주말 20,000 | 파티(모임)공간-주간 25,000 | 파티(모임)공간-주말 30,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1672.00',
#      'marker': 'nres://marker/00063-00035',
#      'markerSelected': 'nres://marker/00063-00188',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '6',
#      'rank': '7',
#      'id': '1062946851',
#      'name': '공간ABC',
#      'tel': '010-3307-9196',
#      'isCallLink': False,
#      'virtualTel': '0507-1322-9196',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 독산동 1007-13',
#      'roadAddress': '서울특별시 금천구 범안로 1212 이편안세상 오피스텔 상가 104호 공간ABC',
#      'abbrAddress': '독산동 1007-13',
#      'shortAddress': ['서울 금천구', '범안로 1212', '이편안세상 오피스텔 상가 104호 공간ABC'],
#      'display': '공간ABC',
#      'telDisplay': '010-3307-9196',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': '47825076d00d132d7e682dcf9b11558f',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200523_235/1590180706416qSAyT_JPEG/l-KLc4ZLbbz5gKo03Janj5kw.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8962748',
#      'y': '37.4662736',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '6Wb+0UQ/4x6EH48hLEW7OA==',
#       'pan': '177.32',
#       'tilt': '10.00',
#       'lng': '126.8962640',
#       'lat': '37.4664971',
#       'fov': '120'},
#      'skyPanorama': {'id': 'UFB5dDgks9yV7YBY5QI29g==',
#       'pan': '93.83',
#       'tilt': '-30.00',
#       'lng': '126.8936081',
#       'lat': '37.4664497',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': None,
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 09:00~21:00',
#      'menuInfo': '공간ABC쥬스 3,900 | 딸바쥬스 3,900 | 망고스무디 4,300 | 레몬에이드 3,900 | 자몽차 3,300 | 바닐라카페라떼ICE 3,500 | 흑당버블밀크티  4,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1893.68',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '7',
#      'rank': '8',
#      'id': '1012458830',
#      'name': '데스트로커피',
#      'tel': '02-868-3255',
#      'isCallLink': False,
#      'virtualTel': '0507-1363-3255',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 가산동 715',
#      'roadAddress': '서울특별시 금천구 범안로 1138 101-1호',
#      'abbrAddress': '가산동 715',
#      'shortAddress': ['서울 금천구', '범안로 1138', '101-1호'],
#      'display': '데스트로커피',
#      'telDisplay': '02-868-3255',
#      'context': [],
#      'reviewCount': 4,
#      'ktCallMd': '658f1de4132ba3e3315bc0a06b273837',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20190722_35/1563785671856pBDMz_JPEG/9FXnFY_qeTCIW32SRZsZTz0E.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8883982',
#      'y': '37.4657937',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'z9YTjwOHam5Hy9E2aQz+xg==',
#       'pan': '85.36',
#       'tilt': '10.00',
#       'lng': '126.8881212',
#       'lat': '37.4657710',
#       'fov': '120'},
#      'skyPanorama': {'id': 'QOpYoVt/Ujjhf9zOU+OEjQ==',
#       'pan': '-173.66',
#       'tilt': '-30.00',
#       'lng': '126.8888092',
#       'lat': '37.4694443',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.instagram.com/destro_coffee',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.888369,
#         'y': 37.465378}],
#       'walk': [{'rep': True, 'x': 126.8881861, 'y': 37.4657996}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '평일 08:00~21:00 | 주말 10:00~17:00',
#      'menuInfo': '에스프레소 2,900 | 아메리카노 2,900 | 카페라떼 3,500 | 카푸치노 3,500 | 바닐라라떼 3,900 | 카페모카 3,900 | 카라멜마끼야또 3,900 | 초코라떼 3,800 | 레몬에이드 4,300 | 자몽에이드 4,300 | 요거트스무디 4,000 | 딸기요거트스무디 4,500 | 블루베리요거트스무디 4,500 | 미숫가루 4,000 | 제주봄빛그린티라떼 4,200 | 고구마라떼 4,200 | 청포도에이드 4,100 | 잉글리쉬 브랙패스트 3,000 | 얼그레이 3,000 | 페퍼민트 3,000 | 카모마일 3,000 | 토마토주스 4,100 | 키위주스 4,100',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1658.22',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '8',
#      'rank': '9',
#      'id': '1550852077',
#      'name': '카페윈썸',
#      'tel': '010-5435-3765',
#      'isCallLink': False,
#      'virtualTel': '0507-1301-3765',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 독산동 1007-13',
#      'roadAddress': '서울특별시 금천구 범안로 1212 상업시설 B07호 카페윈썸',
#      'abbrAddress': '독산동 1007-13',
#      'shortAddress': ['서울 금천구', '범안로 1212', '상업시설 B07호 카페윈썸'],
#      'display': '<b>카페</b>윈썸',
#      'telDisplay': '010-5435-3765',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': 'e7ee5ea5a05a9a98e588236d3f0889d9',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200313_136/1584077004364Nd3dR_JPEG/nvNnQQzS0wu84vyMI_SSdYzC.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8962641',
#      'y': '37.4660352',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'OPEWDHelRnJOEnNkdQMNZA==',
#       'pan': '87.03',
#       'tilt': '10.00',
#       'lng': '126.8958895',
#       'lat': '37.4660155',
#       'fov': '120'},
#      'skyPanorama': {'id': 'UFB5dDgks9yV7YBY5QI29g==',
#       'pan': '98.92',
#       'tilt': '-30.00',
#       'lng': '126.8936081',
#       'lat': '37.4664497',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://instagram.com/cafe_winsome ',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.896658,
#         'y': 37.4659243},
#        {'rep': False, 'x': 126.8959125, 'y': 37.4654874}],
#       'walk': None},
#      'isPollingPlace': False,
#      'bizhourInfo': '토요일 09:00~21:00 | 목요일 09:00~21:00 | 금요일 09:00~21:00 | 수요일 09:00~21:00 | 화요일 09:00~21:00 | 월요일 09:00~21:00 | 공휴일 12:00~18:00 | 일요일 12:00~18:00',
#      'menuInfo': '아메리카노 3,500 | 리얼초코 5,500',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': 'https://booking.naver.com/booking/6/bizes/337515',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': True,
#      'reservationLabel': {'standard': False,
#       'preOrder': True,
#       'table': False,
#       'takeout': True},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': True,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1915.09',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '9',
#      'rank': '10',
#      'id': '21795497',
#      'name': '빅푸드시스템',
#      'tel': '02-3667-9497',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 독산동 1003-5',
#      'roadAddress': '서울특별시 금천구 범안로 1162 4층402호',
#      'abbrAddress': '독산동 1003-5',
#      'shortAddress': ['서울 금천구', '범안로 1162', '4층402호'],
#      'display': '빅푸드시스템',
#      'telDisplay': '02-3667-9497',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': '1a4a32ac4a87f47ea943c47086f6eba8',
#      'coupon': '0',
#      'thumUrl': None,
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8909240',
#      'y': '37.4662070',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'W8eeqBXeDv7jOE7nj8Y9bw==',
#       'pan': '176.76',
#       'tilt': '10.00',
#       'lng': '126.8909061',
#       'lat': '37.4665146',
#       'fov': '120'},
#      'skyPanorama': {'id': 'UFB5dDgks9yV7YBY5QI29g==',
#       'pan': '-95.21',
#       'tilt': '-30.00',
#       'lng': '126.8936081',
#       'lat': '37.4664497',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.atimellow.com/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.890834,
#         'y': 37.466407}],
#       'walk': [{'rep': True, 'x': 126.890834, 'y': 37.466407}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 00:00~24:00',
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1679.40',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '10',
#      'rank': '11',
#      'id': '1355921434',
#      'name': 'GS25 독산우시장점',
#      'tel': '02-6015-6222',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['생활,편의', '편의점'],
#      'categoryPath': [['223267', '223271', '223309'],
#       ['222606', '222607', '1004452']],
#      'address': '서울특별시 금천구 독산동 293-21',
#      'roadAddress': '서울특별시 금천구 범안로 1201',
#      'abbrAddress': '독산동 293-21',
#      'shortAddress': ['서울 금천구', '범안로 1201'],
#      'display': 'GS25 독산우시장점',
#      'telDisplay': '02-6015-6222',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': '982d529e7ef854f3aaeefe1ba6ae2253',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200429_46/1588128581843dWhxn_JPEG/6Jimd-SH0NobmW0HBafiVQcz.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8953492',
#      'y': '37.4666729',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '7UTcvqdqm6q3BQL1VeJfWQ==',
#       'pan': '-23.91',
#       'tilt': '5.38',
#       'lng': '126.8954148',
#       'lat': '37.4665069',
#       'fov': '38'},
#      'skyPanorama': {'id': 'UFB5dDgks9yV7YBY5QI29g==',
#       'pan': '82.73',
#       'tilt': '-30.00',
#       'lng': '126.8936081',
#       'lat': '37.4664497',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': None,
#      'isPollingPlace': False,
#      'bizhourInfo': None,
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1811.29',
#      'marker': 'nres://marker/00063-00052',
#      'markerSelected': 'nres://marker/00063-00205',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '11',
#      'rank': '12',
#      'id': '1634193652',
#      'name': '명장시대',
#      'tel': '02-898-1883',
#      'isCallLink': False,
#      'virtualTel': '0507-1330-1883',
#      'ppc': '1',
#      'category': ['카페,디저트', '베이커리'],
#      'categoryPath': [['220036', '220052', '220564', '221161'],
#       ['222606', '222607', '1004380', '1004381', '1004382']],
#      'address': '경기도 광명시 하안동 342-3',
#      'roadAddress': '경기도 광명시 범안로 930 명장시대',
#      'abbrAddress': '하안동 342-3',
#      'shortAddress': ['경기 광명시', '범안로 930', '명장시대'],
#      'display': '명장시대',
#      'telDisplay': '02-898-1883',
#      'context': [],
#      'reviewCount': 689,
#      'ktCallMd': 'abe9b2b02e33a268a1ed8ec29df10e09',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200512_127/1589288788754gXHCd_JPEG/sHr3SzKediC-VHIJViUEFoMa.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8684659',
#      'y': '37.4553749',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'HumfTwKFOqNxR/IRvR8ljg==',
#       'pan': '149.66',
#       'tilt': '28.18',
#       'lng': '126.8681708',
#       'lat': '37.4558059',
#       'fov': '100'},
#      'skyPanorama': {'id': 'It9kmsbOtWjtA8YDD2ls1g==',
#       'pan': '-106.06',
#       'tilt': '-30.00',
#       'lng': '126.8702774',
#       'lat': '37.4558945',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': None,
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 10:00~22:00',
#      'menuInfo': '내마음속 시나몬 6,000 | 그린올리바 1,500 | 둥근산 연인 6,500 | 와인스틱 6,000 | 찹쌀떡 1,600 | 견과류 카스테라 4,300 | 무화과 깜빠뉴 5,000 | 크림치즈 깜빠뉴 6,000 | 뺑오쇼콜라 3,500 | 베이비크림치즈 2,500 | 나가사키 카스테라 4,500 | 머랭쿠키 5,000 | 인절미빵 6,000 | 프룬스콘 2,800 | 얼그레이스콘 2,800 | 유자찰치즈 3,900 | 시크릿플라워 5,300 | 치즈브리오슈 6,000 | 소세지빵 4,500 | 우리밀 바닐라 3,300 | 브라우니쿠키 3,000 | 레몬파이 4,200 | 애플파이 2,800 | 밤크로와상 5,500 | 폴인크루아상 2,800 | 딸기생크림 7,000 | 당근케이크 6,000 | 기리쉬케이크 6,000 | 티라미수 6,000 | 녹차티라미수 6,000 | 블루베리타르트 5,000 | 망고타르트 5,000 | 딸기타르트 5,000 | 레몬타르트 5,000 | 쇼콜라타르트 5,000 | 크림치즈토르테 5,000 | 에그타르트 2,500 | 먹물치아바타 샌드위치 4,500 | 치아바타 샌드위치 4,500 | 팥빵 2,200 | 어니언크림치즈 6,000 | 딸기크루아상 4,500 | 봄의왈츠 5,800 | 오곡쿠키 6,000 | 건강러스크 2,000 | 코코앤망고 3,500 | 베이비만쥬 6,000 | 브라우니볼 4,800',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '3101.39',
#      'marker': 'nres://marker/00063-00013',
#      'markerSelected': 'nres://marker/00063-00166',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '12',
#      'rank': '13',
#      'id': '1840461185',
#      'name': '라그레이',
#      'tel': '010-2547-3495',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['음식점', '카페,디저트'],
#      'categoryPath': [['220036', '220052', '220563'],
#       ['222606', '222607', '1004380', '1004381', '1004382']],
#      'address': '경기도 광명시 하안동 296-3',
#      'roadAddress': '경기도 광명시 범안로 1030',
#      'abbrAddress': '하안동 296-3',
#      'shortAddress': ['경기 광명시', '범안로 1030'],
#      'display': '라그레이',
#      'telDisplay': '010-2547-3495',
#      'context': [],
#      'reviewCount': 113,
#      'ktCallMd': '963d6afd071be708623d682b187270d1',
#      'coupon': '0',
#      'thumUrl': None,
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8778247',
#      'y': '37.4612098',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '3Gneq5nF8Nn0GYsM03R+PA==',
#       'pan': '134.60',
#       'tilt': '10.00',
#       'lng': '126.8776818',
#       'lat': '37.4613505',
#       'fov': '120'},
#      'skyPanorama': {'id': '7CBuyoMCuCJ3NMuGB7loVA==',
#       'pan': '-83.60',
#       'tilt': '-30.00',
#       'lng': '126.8834457',
#       'lat': '37.4605751',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.instagram.com/la__grey',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.877881,
#         'y': 37.461376}],
#       'walk': [{'rep': True, 'x': 126.877881, 'y': 37.461376}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 11:00~20:00 (마카롱 소진시 마감)',
#      'menuInfo': '마카롱 2,000 | 아메리카노 2,500',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '2197.58',
#      'marker': 'nres://marker/00063-00038',
#      'markerSelected': 'nres://marker/00063-00191',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '13',
#      'rank': '14',
#      'id': '835973645',
#      'name': '옴마카롱',
#      'tel': '010-2087-2502',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['카페,디저트', '베이커리'],
#      'categoryPath': [['220036', '220052', '220564', '221161'],
#       ['222606', '222607', '1004380', '1004381', '1004382']],
#      'address': '경기도 광명시 하안동 33-6',
#      'roadAddress': '경기도 광명시 범안로 1061 삼전빌딩 4층',
#      'abbrAddress': '하안동 33-6',
#      'shortAddress': ['경기 광명시', '범안로 1061', '삼전빌딩 4층'],
#      'display': '옴마카롱',
#      'telDisplay': '010-2087-2502',
#      'context': [],
#      'reviewCount': 71,
#      'ktCallMd': 'e38c9d622b54e1f25be19f6b08db3f61',
#      'coupon': '0',
#      'thumUrl': None,
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8803078',
#      'y': '37.4632277',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '72ZA9V1BQK63ylZYrg8v0A==',
#       'pan': '-40.86',
#       'tilt': '10.00',
#       'lng': '126.8804548',
#       'lat': '37.4630577',
#       'fov': '120'},
#      'skyPanorama': {'id': '8vbRslFMgubh1Q1uTref6A==',
#       'pan': '-90.74',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4632645',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.instagram.com/om_macaron',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True, 'x': 126.880325, 'y': 37.46336}],
#       'walk': [{'rep': True, 'x': 126.8803, 'y': 37.463102}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '월요일 휴무 | 매일 11:00~20:00 조금씩 다를 수 있음 | 주말 12:00~17:00 조금씩 다를 수 있음',
#      'menuInfo': '마카롱 2,500',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1930.86',
#      'marker': 'nres://marker/00063-00013',
#      'markerSelected': 'nres://marker/00063-00166',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '14',
#      'rank': '15',
#      'id': '1375564182',
#      'name': '르하임스터디카페 광명하안점',
#      'tel': '010-6348-7899',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['서비스,산업', '장소대여'],
#      'categoryPath': [['225111', '225130', '229970', '229971'],
#       ['222606', '222607', '1004380', '1004381', '1004382']],
#      'address': '경기도 광명시 하안동 34-5 성원빌딩 8층',
#      'roadAddress': '경기도 광명시 범안로 1049 성원빌딩 8층',
#      'abbrAddress': '하안동 34-5 성원빌딩 8층',
#      'shortAddress': ['경기 광명시', '범안로 1049', '성원빌딩 8층'],
#      'display': '르하임스터디<b>카페</b> 광명하안점',
#      'telDisplay': '010-6348-7899',
#      'context': [],
#      'reviewCount': 97,
#      'ktCallMd': '82bd99762b83be4319d766185cc2fe87',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20180721_173/15321461817399eMaK_JPEG/lv9OKj99Ar_08dusglPXBNSY.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8793078',
#      'y': '37.4627190',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'AHcs8Koh+GIJwzYL8yAPiw==',
#       'pan': '-34.16',
#       'tilt': '10.00',
#       'lng': '126.8794551',
#       'lat': '37.4625020',
#       'fov': '120'},
#      'skyPanorama': {'id': '8vbRslFMgubh1Q1uTref6A==',
#       'pan': '-97.77',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4632645',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'https://blog.naver.com/siso0435',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.8791654,
#         'y': 37.4627628}],
#       'walk': [{'rep': True, 'x': 126.8793508, 'y': 37.4628762}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 00:00~24:00 연중무휴',
#      'menuInfo': '2시간 3,000 | 4시간 5,000 | 6시간 6,000 | 9시간 8,000 | 12시간 10,000 | 50시간 정액권 70,000 | 100시간 정액권 120,000 | 4주 기간권 120,000 | 4인 스터디룸 1시간 7,000 | 4인 스터디룸 20시간 정액권 120,000 | 4인 스터디룸 30시간 정액권 180,000 | 6인 스터디룸 1시간 10,000 | 6인 스터디룸 20시간 정액권 180,000 | 6인 스터디룸 30시간 정액권 270,000 | 8인 스터디룸  1시간 12,000 | 8인 스터디룸 20시간 정액권 220,000 | 8인 스터디룸 30시간 정액권 330,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '2003.60',
#      'marker': 'nres://marker/00063-00035',
#      'markerSelected': 'nres://marker/00063-00188',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '15',
#      'rank': '16',
#      'id': '35788342',
#      'name': '스타벅스 광명하안점',
#      'tel': '1522-3232',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['카페,디저트', '카페'],
#      'categoryPath': [['220036', '220052', '220576', '221275']],
#      'address': '경기도 광명시 하안동 53-3',
#      'roadAddress': '경기도 광명시 범안로 1060',
#      'abbrAddress': '하안동 53-3',
#      'shortAddress': ['경기 광명시', '범안로 1060'],
#      'display': '스타벅스 광명하안점',
#      'telDisplay': '1522-3232',
#      'context': [],
#      'reviewCount': 46,
#      'ktCallMd': '7e663c2a3a77ea5bf4110dbb3eb6abfb',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20190828_93/1566953601239OT9MQ_PNG/xX7Wv642gXMoTI0DAv0hRymS.png',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8805770',
#      'y': '37.4626050',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'YUq+3OLBH59N5XNlztvnKg==',
#       'pan': '112.06',
#       'tilt': '6.31',
#       'lng': '126.8802800',
#       'lat': '37.4627877',
#       'fov': '63'},
#      'skyPanorama': {'id': '8vbRslFMgubh1Q1uTref6A==',
#       'pan': '-103.52',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4632645',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.starbucks.co.kr/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.880603,
#         'y': 37.462524}],
#       'walk': [{'rep': True, 'x': 126.880541, 'y': 37.46278}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '화요일 07:00~22:00 | 수요일 07:00~22:00 | 목요일 07:00~22:00 | 금요일 07:00~22:00 | 토요일 07:00~22:00 | 일요일 08:00~22:00 | 월요일 07:00~22:00',
#      'menuInfo': '블론드 서머 라떼 5,900 | 스위티 자몽&라임 블렌디드 6,300 | 스위트 멜론 블렌디드 6,300 | 카페 아메리카노 4,100 | 디카페인 카페 아메리카노 4,400 | 카페 라떼 4,600 | 디카페인 카페 라뗴 4,900 | 오늘의 커피 3,800 | 스타벅스 돌체 라떼 5,600 | 카라멜 마키아또 5,600 | 카푸치노 4,600 | 카페 모카 5,100 | 화이트 초콜릿 모카 5,600 | 콜드 브루 4,500 | 자몽 허니 블랙 티 5,300 | 아이스 자몽 허니 블랙 티 5,300 | 망고 바나나 블렌디드 6,300 | 에스프레소 프라푸치노 5,100 | 자바 칩 프라푸치노 6,100',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
# ...
#       'pan': '-40.86',
#       'tilt': '10.00',
#       'lng': '126.8804548',
#       'lat': '37.4630577',
#       'fov': '120'},
#      'skyPanorama': {'id': '8vbRslFMgubh1Q1uTref6A==',
#       'pan': '-90.74',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4632645',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': '',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True, 'x': 126.880325, 'y': 37.46336}],
#       'walk': [{'rep': True, 'x': 126.8803, 'y': 37.463102}]},
#      'isPollingPlace': False,
#      'bizhourInfo': None,
#      'menuInfo': '오징어볶음 10,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1930.86',
#      'marker': 'nres://marker/00063-00122',
#      'markerSelected': 'nres://marker/00063-00276',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '31',
#      'rank': '32',
#      'id': '37535308',
#      'name': '티움심리상담센터',
#      'tel': '02-898-2777',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['건강,의료', '심리상담'],
#      'categoryPath': [['223175', '223180', '223196'],
#       ['222606', '222607', '1004380', '1004381', '1004382']],
#      'address': '경기도 광명시 하안동 36 골드프라자 5층',
#      'roadAddress': '경기도 광명시 범안로 1040',
#      'abbrAddress': '하안동 36 골드프라자 5층',
#      'shortAddress': ['경기 광명시', '범안로 1040'],
#      'display': '티움심리상담센터',
#      'telDisplay': '02-898-2777',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': 'c1aa1bb87b5250cb9cff313fca64f86e',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20160201_32/1454324726581v5JPV_JPEG/176077533664766_0.jpeg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8787075',
#      'y': '37.4616493',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '7SdS0fHi7x79msYK2kiGeg==',
#       'pan': '147.07',
#       'tilt': '10.00',
#       'lng': '126.8785708',
#       'lat': '37.4618599',
#       'fov': '120'},
#      'skyPanorama': {'id': '/Bm0DOs5sWrP3iGsZIYxwQ==',
#       'pan': '-100.27',
#       'tilt': '-30.00',
#       'lng': '126.8834991',
#       'lat': '37.4625130',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://www.tiumcafe.net',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.878837,
#         'y': 37.4615729}],
#       'walk': [{'rep': True, 'x': 126.8786007, 'y': 37.4617207}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 09:00~21:00',
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '2131.38',
#      'marker': 'nres://marker/00063-00035',
#      'markerSelected': 'nres://marker/00063-00188',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '32',
#      'rank': '33',
#      'id': '1139506342',
#      'name': '포텐스터디센터 하안점',
#      'tel': '010-4695-9253',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['교육,학문', '독서실'],
#      'categoryPath': [['222412', '222415', '222446', '231974']],
#      'address': '경기도 광명시 하안동 34-10',
#      'roadAddress': '경기도 광명시 범안로 1041',
#      'abbrAddress': '하안동 34-10',
#      'shortAddress': ['경기 광명시', '범안로 1041'],
#      'display': '포텐스터디센터 하안점',
#      'telDisplay': '010-4695-9253',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': '95bdb93b727b2fd25836fef7699482ce',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200618_5/1592443569956RyPA7_JPEG/Ohtkgr6nvjGSLZYkw_9bq0a5.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8784852',
#      'y': '37.4622410',
#      'itemLevel': '8',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'VByGYSpJPmDON4ke6Is/VQ==',
#       'pan': '-42.82',
#       'tilt': '10.00',
#       'lng': '126.8786553',
#       'lat': '37.4620573',
#       'fov': '120'},
#      'skyPanorama': {'id': '8vbRslFMgubh1Q1uTref6A==',
#       'pan': '-101.98',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4632645',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'https://potenstudy.creatorlink.net/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.878363,
#         'y': 37.462336}],
#       'walk': [{'rep': True, 'x': 126.878594, 'y': 37.462177}]},
#      'isPollingPlace': False,
#      'bizhourInfo': '매일 00:00~24:00',
#      'menuInfo': '1시간(커피/음료/쿠키 무료) 2,000 | 2시간(커피/음료/쿠키 무료) 3,000 | 4시간(커피/음료/쿠키 무료) 5,000 | 6시간(커피/음료/쿠키 무료) 6,000 | 2인 스터디룸 6,000 | 4인 스터디룸 8,000',
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '1',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '2071.94',
#      'marker': 'nres://marker/00063-00035',
#      'markerSelected': 'nres://marker/00063-00188',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '33',
#      'rank': '34',
#      'id': '18939012',
#      'name': 'GS25 광명유창점',
#      'tel': '02-897-7864',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['생활,편의', '편의점'],
#      'categoryPath': [['223267', '223271', '223309'],
#       ['222606', '222607', '1004380', '1004381', '1004382']],
#      'address': '경기도 광명시 하안동 33-5 유창빌딩 102호',
#      'roadAddress': '경기도 광명시 범안로 1059 유창빌딩',
#      'abbrAddress': '하안동 33-5 유창빌딩 102호',
#      'shortAddress': ['경기 광명시', '범안로 1059', '유창빌딩'],
#      'display': 'GS25 광명유창점',
#      'telDisplay': '02-897-7864',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': 'b2f035602ded665fe34d2aa7a184701f',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200121_31/1579571495458ARLtG_JPEG/2ug5eW43vnQfXFFyfpkdQEwn.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8800850',
#      'y': '37.4630371',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'rWG2sAJGQdh8rGwsj1VJBw==',
#       'pan': '-25.52',
#       'tilt': '10.00',
#       'lng': '126.8801548',
#       'lat': '37.4628910',
#       'fov': '120'},
#      'skyPanorama': {'id': '8vbRslFMgubh1Q1uTref6A==',
#       'pan': '-94.05',
#       'tilt': '-30.00',
#       'lng': '126.8833313',
#       'lat': '37.4632645',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://gs25.gsretail.com/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.8799914,
#         'y': 37.4631923}],
#       'walk': [{'rep': True, 'x': 126.8802048, 'y': 37.4630671}]},
#      'isPollingPlace': False,
#      'bizhourInfo': None,
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '1955.26',
#      'marker': 'nres://marker/00063-00052',
#      'markerSelected': 'nres://marker/00063-00205',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '34',
#      'rank': '35',
#      'id': '18937935',
#      'name': 'GS25 광명녹원점',
#      'tel': '02-897-9545',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['생활,편의', '편의점'],
#      'categoryPath': [['223267', '223271', '223309'], ['223267', '223284']],
#      'address': '경기도 광명시 하안동 302 녹원프라자 106,107호',
#      'roadAddress': '경기도 광명시 범안로 998',
#      'abbrAddress': '하안동 302 녹원프라자 106,107호',
#      'shortAddress': ['경기 광명시', '범안로 998'],
#      'display': 'GS25 광명녹원점',
#      'telDisplay': '02-897-9545',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': '090b7a71a6691909bf8fba5cfc528112',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200121_31/1579571495458ARLtG_JPEG/2ug5eW43vnQfXFFyfpkdQEwn.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8748731',
#      'y': '37.4593564',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': 'nlG1eHuNvJNPm94eu5zM4w==',
#       'pan': '133.55',
#       'tilt': '10.00',
#       'lng': '126.8746590',
#       'lat': '37.4595596',
#       'fov': '120'},
#      'skyPanorama': {'id': 'I8CLAvMaOEruDmGOE7cQ4A==',
#       'pan': '80.90',
#       'tilt': '-30.00',
#       'lng': '126.8701172',
#       'lat': '37.4585915',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://gs25.gsretail.com/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.875041,
#         'y': 37.459411}],
#       'walk': [{'rep': True, 'x': 126.874876, 'y': 37.459575}]},
#      'isPollingPlace': False,
#      'bizhourInfo': None,
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '2471.44',
#      'marker': 'nres://marker/00063-00052',
#      'markerSelected': 'nres://marker/00063-00205',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None},
#     {'index': '35',
#      'rank': '36',
#      'id': '32160934',
#      'name': 'GS25 광명프라자점',
#      'tel': '02-898-1767',
#      'isCallLink': False,
#      'virtualTel': '',
#      'ppc': '1',
#      'category': ['생활,편의', '편의점'],
#      'categoryPath': [['223267', '223271', '223309'],
#       ['222606', '222607', '1004452']],
#      'address': '경기도 광명시 하안동 36 골드프라자 105호',
#      'roadAddress': '경기도 광명시 범안로 1040',
#      'abbrAddress': '하안동 36 골드프라자 105호',
#      'shortAddress': ['경기 광명시', '범안로 1040'],
#      'display': 'GS25 광명프라자점',
#      'telDisplay': '02-898-1767',
#      'context': [],
#      'reviewCount': 0,
#      'ktCallMd': 'c0c390452e1438a132667dae6292e424',
#      'coupon': '0',
#      'thumUrl': 'http://ldb.phinf.naver.net/20200121_31/1579571495458ARLtG_JPEG/2ug5eW43vnQfXFFyfpkdQEwn.jpg',
#      'type': 's',
#      'isSite': '1',
#      'posExact': '1',
#      'x': '126.8785798',
#      'y': '37.4616598',
#      'itemLevel': '12',
#      'isAdultBusiness': False,
#      'streetPanorama': {'id': '1iy/7hUc8ET9U6mwApqdlQ==',
#       'pan': '143.10',
#       'tilt': '10.00',
#       'lng': '126.8784715',
#       'lat': '37.4618038',
#       'fov': '120'},
#      'skyPanorama': {'id': '/Bm0DOs5sWrP3iGsZIYxwQ==',
#       'pan': '-99.89',
#       'tilt': '-30.00',
#       'lng': '126.8834991',
#       'lat': '37.4625130',
#       'fov': '124'},
#      'insidePanorama': None,
#      'interiorPanorama': None,
#      'indoorPanorama': None,
#      'theme': None,
#      'poiInfo': {'relation': None,
#       'hasRelation': False,
#       'road': {'poiShapeType': '1',
#        'shapeKey': None,
#        'boundary': None,
#        'detail': None},
#       'hasRoad': False,
#       'land': None,
#       'hasLand': False,
#       'polygon': None,
#       'hasPolygon': False},
#      'homePage': 'http://gs25.gsretail.com/',
#      'description': '',
#      'entranceCoords': {'car': [{'rep': True,
#         'x': 126.878837,
#         'y': 37.4615729}],
#       'walk': [{'rep': True, 'x': 126.8786007, 'y': 37.4617207}]},
#      'isPollingPlace': False,
#      'bizhourInfo': None,
#      'menuInfo': None,
#      'petrolInfo': None,
#      'couponUrl': None,
#      'couponUrlMobile': None,
#      'hasCardBenefit': False,
#      'menuExist': '0',
#      'hasNaverBooking': False,
#      'naverBookingUrl': '',
#      'naverEasyOrderUrl': None,
#      'hasNaverSmartOrder': False,
#      'reservationLabel': {'standard': False,
#       'preOrder': False,
#       'table': False,
#       'takeout': False},
#      'hasBroadcastInfo': False,
#      'broadcastInfo': None,
#      'shopWindowInfo': None,
#      'hasNPay': False,
#      'carWash': '',
#      'parkingPrice': '-1',
#      'card': '',
#      'distance': '2132.82',
#      'marker': 'nres://marker/00063-00052',
#      'markerSelected': 'nres://marker/00063-00205',
#      'microReview': [],
#      'michelinGuide': None,
#      'indoor': None,
#      'markerLabel': None,
#      'subway': None}]},
#   'bus': None}}
